# %% [markdown]
# 1 - This is a single long line and if we make a change to it midway then the diff should render correctly with line wrapping on highlighted diff part. We don't want inline-block property on diff to cause incorrect rendering.

# %% [markdown]
# 2 - This is a single long line and if we make a change to it midway then the diff should render correctly with line wrapping on highlighted diff part. We don't want inline-block property on diff to cause incorrect rendering.

# %% [markdown]
# 3 - This is a single long line and if we make a change to it midway then the diff should render correctly with line wrapping on highlighted diff part. We don't want inline-block property on diff to cause incorrect rendering.

# %% [markdown]
# 4 - This is a single long line and if we make a change to it midway then the diff should render correctly with line wrapping on highlighted diff part. We don't want inline-block property on diff to cause incorrect rendering.
