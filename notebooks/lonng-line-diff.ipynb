# %% [markdown]
# 1 - This is a single long line and if we make a change to it midway then the diff - this is a long newly added section between two dashesh to test line wrapping behaviour on super long lines - should render correctly with line wrapping on highlighted diff part. We don't want inline-block property on diff to cause incorrect rendering.

# %% [markdown]
# 2 - This is a single

# %% [markdown]
# 3 - This is a line where large middle part of the lines is deleted and now we are just adding superfluous text to see how wrapping works on the modified line rendering.

# %% [markdown]
# small starting part added 4 - This is a single long line and if we make a change to it midway and then long last part deleted and replaced with some superfluous text for some more testing
