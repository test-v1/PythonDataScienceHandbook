# %% [markdown]
# print(a)
#     return x
# # heading

# %% [markdown]
# lat = "$\\nabla f$"

# %%
x = 1
a = "C:\\new"
x = 1
# Out:
# line1
# line2
# plt.show()
# import numpy as np
# lat = "$\\nabla f$"
#     return x

# %%
print(a)
    return x
# Out:
# line1
# line2
# a = "C:\\new"
# print(a)

# %% [markdown]
# x = 1
# plt.show()
